# %%
#Research Project: Analyze Student Test Performace. Review Dataset and compare schools.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# # Research Question: How does the test volume and mean score of Bronx Lighthouse Charter School(K-12) compare to K -12 school in Brooklyn?

# %% [markdown]
# # Data Familiarization Review

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %% [markdown]
# Cleaning Data

# %%
df.replace('s','4',inplace = True)
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          4                       4
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          4                       4
# 4  Common Core Algebra  2017             2          4                       4
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        4                          4
# ...

# %% [markdown]
# Familiarizing with Data Set

# %%
df.groupby('School Name').count()
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
# ...

# %%
df.groupby('Regents Exam').count()
# Out:
#                                  School DBN  School Name  School Level   Year  \
# Regents Exam
# Algebra2/Trigonometry                 10788        10788         10788  10788
# Common Core Algebra                   29254        29254         29254  29254
# Common Core Algebra2                   7915         7915          7915   7915
# Common Core English                   19878        19878         19878  19878
# Common Core Geometry                  15267        15267         15267  15267
# English                               11091        11091         11091  11091
# Geometry                               8509         8509          8509   8509
# Global History and Geography          19192        19192         19192  19192
# Integrated Algebra                    11022        11022         11022  11022
# Living Environment                    25539        25539         25539  25539
# Physical Settings/Chemistry           11670        11670         11670  11670
# ...

# %% [markdown]
# Clean Data and Drop all School Levels not being used in analysis.
# Create new data frame to manage and review data set.

# %%
df[df['School Level']=="K-12 all grades"]
# Out:
#        School DBN                                        School Name  \
# 192        01M539  New Explorations into Science, Technology and ...
# 193        01M539  New Explorations into Science, Technology and ...
# 194        01M539  New Explorations into Science, Technology and ...
# 195        01M539  New Explorations into Science, Technology and ...
# 196        01M539  New Explorations into Science, Technology and ...
# ...           ...                                                ...
# 212297     84X704                        KIPP Academy Charter School
# 212298     84X704                        KIPP Academy Charter School
# 212299     84X704                        KIPP Academy Charter School
# 212300     84X704                        KIPP Academy Charter School
# 212301     84X704                        KIPP Academy Charter School
#
#            School Level                 Regents Exam  Year  Total Tested  \
# ...

# %%
df2 = df[df['School Level']=="K-12 all grades"]
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          4                       4
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          4                       4
# 4  Common Core Algebra  2017             2          4                       4
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        4                          4
# ...

# %% [markdown]
# Created new data frame with needed columns to complete analysis.
# Confirmation of dropped columns not needed.

# %%
df3 = df2[['School Name', 'Regents Exam', 'Year', 'Total Tested', 'Mean Score']]
df3.head()
# Out:
#                                            School Name           Regents Exam  \
# 192  New Explorations into Science, Technology and ...  Algebra2/Trigonometry
# 193  New Explorations into Science, Technology and ...  Algebra2/Trigonometry
# 194  New Explorations into Science, Technology and ...    Common Core Algebra
# 195  New Explorations into Science, Technology and ...    Common Core Algebra
# 196  New Explorations into Science, Technology and ...    Common Core Algebra
#
#      Year  Total Tested Mean Score
# 192  2015           180       80.7
# 193  2016           175       80.6
# 194  2015            74       78.3
# 195  2016           207       83.1
# 196  2017           179       84.8

# %%
df3.describe()
# Out:
#               Year  Total Tested
# count  8294.000000   8294.000000
# mean   2016.022667     31.375090
# std       0.813321     35.406554
# min    2015.000000      1.000000
# 25%    2015.000000      5.000000
# 50%    2016.000000     20.000000
# 75%    2017.000000     46.000000
# max    2017.000000    339.000000

# %%
df3.groupby(['School Name'])['Regents Exam'].count()
# Out:
# School Name
# Achievement First Brownsville Charter School           21
# Achievement First Bushwick Charter School             215
# Achievement First Crown Heights Charter School        180
# Achievement First East New York Charter School        150
# Achievement First Endeavor Charter School             189
# Bronx Lighthouse Charter School                       381
# Brooklyn Ascend Charter School                         94
# Brooklyn Prospect Charter School                      404
# Coney Island Preparatory Public Charter School        395
# Democracy Prep Charter School                         355
# Democracy Prep Harlem Charter School                  334
# Excellence Girls Charter School                        91
# Harlem Children's Zone Promise Academy 1 Charter S    309
# Harlem Children's Zone Promise Academy II Charter     272
# Harlem Prep Charter School                             34
# Harlem Village Academy Charter School                 260
# ...

# %% [markdown]
# Bronx Lighthouse Charter School

# %%
df4 = df.loc[(df['School Name']=='Bronx Lighthouse Charter School'),
       ['Regents Exam', 'Year', 'Total Tested', 'Mean Score']]

# %%
df4.describe()
# Out:
#               Year  Total Tested
# count   381.000000    381.000000
# mean   2015.931759     26.771654
# std       0.804961     24.479053
# min    2015.000000      1.000000
# 25%    2015.000000      6.000000
# 50%    2016.000000     20.000000
# 75%    2017.000000     38.000000
# max    2017.000000    117.000000

# %%
df4.groupby(['Regents Exam'])['Year'].count()
#Total Tested each Year
# Out:
# Regents Exam
# Algebra2/Trigonometry              28
# Common Core Algebra                32
# Common Core Algebra2               19
# Common Core English                33
# Common Core Geometry               31
# English                            20
# Geometry                           18
# Global History and Geography       33
# Integrated Algebra                 19
# Living Environment                 32
# Physical Settings/Chemistry        26
# Physical Settings/Earth Science    31
# Physical Settings/Physics          27
# U.S. History and Government        32
# Name: Year, dtype: int64

# %%
df4['Mean Score'].describe
#Average 69
# Out:
# <bound method NDFrame.describe of 18972       69
# 18973       68
# 18974     39.7
# 18975     65.6
# 18976     73.1
#           ...
# 210900    78.4
# 210901    78.6
# 210902       4
# 210903       4
# 210904    68.4
# Name: Mean Score, Length: 381, dtype: object>

# %%
df4.groupby(['Year', 'Total Tested']).count().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Year,Total Tested'>

# %%
df4.groupby

# %% [markdown]
# Brooklyn Prospect Charter School > Common Core English Regents Exam

# %%
df5 = df.loc[(df['School Name']=='Bronx Lighthouse Charter School'),
       ['Regents Exam', 'Year', 'Total Tested', 'Mean Score']]

# %%
df5.describe()
# Out:
#               Year  Total Tested
# count   381.000000    381.000000
# mean   2015.931759     26.771654
# std       0.804961     24.479053
# min    2015.000000      1.000000
# 25%    2015.000000      6.000000
# 50%    2016.000000     20.000000
# 75%    2017.000000     38.000000
# max    2017.000000    117.000000

# %%
df5.groupby(['Regents Exam'])['Year'].count()
#Total Tested each Year
# Out:
# Regents Exam
# Algebra2/Trigonometry              28
# Common Core Algebra                32
# Common Core Algebra2               19
# Common Core English                33
# Common Core Geometry               31
# English                            20
# Geometry                           18
# Global History and Geography       33
# Integrated Algebra                 19
# Living Environment                 32
# Physical Settings/Chemistry        26
# Physical Settings/Earth Science    31
# Physical Settings/Physics          27
# U.S. History and Government        32
# Name: Year, dtype: int64

# %%
df5['Mean Score'].describe
#Average Score 88

# %%
df5.groupby(['Year', 'Total Tested']).count().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Year,Total Tested'>

# %% [markdown]
# Bronx Lighthouse Charter School & Brooklynn Prospect Charter school had a total 381 testers in numerous Regent Exams. Unfortunatley when comparing the school means score avearge Bronx Lighthouse Charter schools 69% average was considerabley lower to Brooklynn Prospect Charter School which reached an average 88% mean score.
